# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv("test.csv", parse_dates=["datetime"])#parse_date 년월일 시분초인 데이터만 사용가능
train = pd.read_csv("train.csv", parse_dates=["datetime"])
display(train.head(),test.head()) #앞에서 부터 5개를 보여줌
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# ...

# %%
train["hour"] = train["datetime"].dt.hour #dt는 날짜모듈
train["year"] = train["datetime"].dt.year
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["weekday"] = train["datetime"].dt.weekday
test["hour"] = test["datetime"].dt.hour #dt는 날짜모듈
test["year"] = test["datetime"].dt.year
test["month"] = test["datetime"].dt.month
test["day"] = test["datetime"].dt.day
test["weekday"] = test["datetime"].dt.weekday

# %%
plt.figure(figsize=(20,12)) #그래프의 판을 만들어주고 figsize가 판사이즈 모든 plt에 적용한다
train.boxplot() #boxplot을 보여주는 그래프 데이터가 숫자를 사분위로 보여준다
# Out:
# <AxesSubplot: >

# %%
train.info() #train이 가지고 있는 dataframe을 보여준다 non-null은 빈 값이 없는지를 확인
#숫자형이 아닌 다른 데이터형들은 object라고 표현
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  hour        10886 non-null  int64
#  13  year        10886 non-null  int64
#  14  month       10886 non-null  int64
#  15  day         10886 non-null  int64
#  16  weekday     10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(13)
# memory usage: 1.4 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   datetime64[ns]
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
#  9   hour        6493 non-null   int64
#  10  year        6493 non-null   int64
#  11  month       6493 non-null   int64
#  12  day         6493 non-null   int64
#  13  weekday     6493 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(10)
# memory usage: 710.3 KB

# %%
sum(train.duplicated()), sum(test.duplicated()) #데이터가 중복 되었는지 확인(병렬 처리)
# Out:
# (0, 0)

# %%
#DATA check
#EDA => 데이터를 하나하나씩 뜯어보는 단계
#Feature Engineering
#Modeling & make submission
train.describe() #데이터의 상세한 갯수
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
test.describe()
# Out:
#             season      holiday   workingday      weather         temp  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed         hour         year  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157    11.555367  2011.503619
# std       8.782741    19.293391     8.250151     6.912526     0.500025
# ...

# %%
train.groupby("year")["count"].sum() #()는 기준 []은 통계할 대상 .mean()은 평균 .sum()은 합계
# Out:
# year
# 2011     781979
# 2012    1303497
# Name: count, dtype: int64

# %%
train.groupby("weekday")["count"].median() #mean은 평균
# Out:
# weekday
# 0    146.0
# 1    146.0
# 2    136.0
# 3    155.0
# 4    167.0
# 5    141.5
# 6    119.0
# Name: count, dtype: float64

# %%
plt.figure(figsize=(20,12)) # 그래프를 그릴 때마다 하나씩해야함
sns.barplot(x = train["year"],y = train["count"])
# Out:
# <AxesSubplot: xlabel='year', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.barplot(x = train["weekday"], y = train["count"])
# Out:
# <AxesSubplot: xlabel='weekday', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.barplot(x = train["month"], y = train["count"])
# Out:
# <AxesSubplot: xlabel='month', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.barplot(x = train["day"], y = train["count"])
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
train["day"].describe()
# Out:
# count    10886.000000
# mean         9.992559
# std          5.476608
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         19.000000
# Name: day, dtype: float64

# %%
test["day"].describe() #day에서보면 train과 test의 날짜를 보면 완전히 다른날짜이므로 제거한다
# Out:
# count    6493.000000
# mean       25.224550
# std         3.339411
# min        20.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        31.000000
# Name: day, dtype: float64

# %%
plt.figure(figsize=(20,12))
sns.barplot(x = train["hour"], y = train["count"])
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x = train["hour"], y = train["count"])
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
fig,(ax1, ax2, ax3, ax4, ax5)=plt.subplots(nrows=5)# 열로 5개를 생성
fig.set_size_inches(18,25)

sns.pointplot(data = train, x='hour', y ='count' , ax = ax1)
sns.pointplot(data = train, x='hour', y ='count' , hue='workingday', ax = ax2) #hue는 조건
sns.pointplot(data = train, x='hour', y ='count' , hue='weekday', ax = ax3)
sns.pointplot(data = train, x='hour', y ='count' , hue='season', ax = ax4)
sns.pointplot(data = train, x='hour', y ='count' , hue='weather', ax = ax5)
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
weekend = train[train["workingday"]==0]
weekday = train[train["workingday"]==1]

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x = train["hour"],y = weekday["count"])
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x = train["hour"],y = weekend["count"])
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.scatterplot(x=train["temp"],y=train["count"])
# Out:
# <AxesSubplot: xlabel='temp', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.scatterplot(x=train["atemp"],y=train["count"])
# Out:
# <AxesSubplot: xlabel='atemp', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.scatterplot(x=train["humidity"],y=train["count"])
# Out:
# <AxesSubplot: xlabel='humidity', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.scatterplot(x=train["windspeed"],y=train["count"])
# Out:
# <AxesSubplot: xlabel='windspeed', ylabel='count'>

# %%
corr = train.corr()['count'].sort_values() #목표하는 count와 train.corr()은 train의 모든column
#humidity은 낮아질수록 더 카운터에 영향 hour는 높을수록 영향 절댓값이 0.1만 넘어도 쓸만하다
#비정상적으로 상관계수가 높은 것은 생각해봐야한다
print("상관계수:\n", corr)
# Out:
# 상관계수:
#  humidity     -0.317371
# weather      -0.128655
# holiday      -0.005393
# weekday      -0.002283
# workingday    0.011594
# day           0.019826
# windspeed     0.101369
# season        0.163439
# month         0.166862
# year          0.260403
# atemp         0.389784
# temp          0.394454
# hour          0.400601
# casual        0.690414
# registered    0.970948
# count         1.000000
# Name: count, dtype: float64
# /var/folders/2w/f8gf1wfd1c7f__62y8nsz8480000gn/T/ipykernel_58162/219310327.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()['count'].sort_values()

# %%
train2 = train.drop(["datetime","casual","registered","count"],axis=1)
train2.drop(["day","month"],axis=1,inplace=True) #1은 열 0은 행 inplace는 train =이랑 똑같은 것
test2 = test.drop(["datetime","day","month"],axis=1)
test2.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    hour  year  weekday
# 0     0  2011        3
# 1     1  2011        3
# 2     2  2011        3
# 3     3  2011        3
# 4     4  2011        3

# %%
train2.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    hour  year  weekday
# 0     0  2011        5
# 1     1  2011        5
# 2     2  2011        5
# 3     3  2011        5
# 4     4  2011        5

# %%
display(train2,test2)
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0           1        0           0        1   9.84  14.395        81
# 1           1        0           0        1   9.02  13.635        80
# 2           1        0           0        1   9.02  13.635        80
# 3           1        0           0        1   9.84  14.395        75
# 4           1        0           0        1   9.84  14.395        75
# ...       ...      ...         ...      ...    ...     ...       ...
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  hour  year  weekday
# 0         0.0000     0  2011        5
# 1         0.0000     1  2011        5
# ...

# %%
plt.figure(figsize=(20,12))
sns.distplot(train["count"]) #데이터의 빈도를 나타냄
# Out:
# /Users/kimbeomsoo/miniforge3/envs/ml/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='count', ylabel='Density'>

# %%
plt.figure(figsize=(20,12))
sns.distplot(np.log(train["count"]))#데이터에log를 사용하면 데이터의 갯수가 기준이아니라 변화가 기준이되어서 정규화가 된다
# Out:
# /Users/kimbeomsoo/miniforge3/envs/ml/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='count', ylabel='Density'>

# %%
from sklearn.ensemble import RandomForestRegressor #트리에서 기준으로 인지 아닌지를 분류해서 분류를 통해 트리를 만든다 숫자로 예측은 regressor 종류는 classifier

model1 = RandomForestRegressor(verbose=1) #모델의 학습진행사항을 보여줌
model1.fit(train2,np.log(train["count"]))
rf_result = model1.predict(test2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
pd.Series(model1.feature_importances_,index=train2.columns).sort_values(ascending=False) #어떤 요소가 가장 결과에 영향을 끼쳤는지 모델의 결과 요약
# Out:
# hour          0.756433
# temp          0.045854
# workingday    0.038956
# season        0.037488
# year          0.031334
# weekday       0.028298
# humidity      0.021237
# atemp         0.016936
# windspeed     0.011000
# weather       0.010886
# holiday       0.001579
# dtype: float64

# %%
print(rf_result)
print(test)
# Out:
# [2.42874775 1.56670202 1.19353374 ... 4.63940846 4.59066504 3.8216707 ]
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# ...                  ...     ...      ...         ...      ...    ...     ...
# 6488 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 6489 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 6490 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 6491 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# ...

# %%
sub = pd.read_csv("sampleSubmission.csv")
sub["count"] =np.exp(rf_result)
sub.head()
# Out:
#               datetime      count
# 0  2011-01-20 00:00:00  11.344667
# 1  2011-01-20 01:00:00   4.790822
# 2  2011-01-20 02:00:00   3.298717
# 3  2011-01-20 03:00:00   3.163789
# 4  2011-01-20 04:00:00   2.625488

# %%
sub.to_csv("sub.csv",index=False)
