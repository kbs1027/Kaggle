# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import tensorflow as tf
#
# File ~/miniforge3/envs/ml/lib/python3.8/site-packages/tensorflow/__init__.py:439
#     437 _plugin_dir = _os.path.join(_s, 'tensorflow-plugins')
#     438 if _os.path.exists(_plugin_dir):
# --> 439   _ll.load_library(_plugin_dir)
#     440   # Load Pluggable Device Library
#     441   _ll.load_pluggable_device_library(_plugin_dir)
#
# File ~/miniforge3/envs/ml/lib/python3.8/site-packages/tensorflow/python/framework/load_library.py:151, in load_library(library_location)
#     148     kernel_libraries = [library_location]
#     150   for lib in kernel_libraries:
# --> 151     py_tf.TF_LoadLibrary(lib)
#     153 else:
#     154   raise OSError(
#     155       errno.ENOENT,
#     156       'The file or folder to load kernel libraries from does not exist.',
# ...

# %%
tf.__version__
